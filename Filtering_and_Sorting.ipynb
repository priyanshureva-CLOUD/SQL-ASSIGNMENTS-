# %%
create table employee(
emp_id int,
emp_name varchar(50),
department varchar(50),
city varchar(60),
salary int,
hire_date date);

insert into employee values(101, "rahul mehta", "sales", "delhi", 55000, '2020-04-12');
insert into employee values(102, "priya sharma", "HR", "mumbai", 62000, '2019-09-25');
insert into employee values(103, "aman singh", "IT", "banglore", 72000, '2021-03-10');
insert into employee values(104, "neha patel", "sales", "delhi", 48000, '2022-10-14');
insert into employee values(105, "karan joshi", "marketing", "pune", 45000, '2018-07-22');
insert into employee values(106, "divya nair", "IT", "chennai", 81000, '2019-12-11');
insert into employee values(107, "raj kumar", "HR", "delhi", 60000, '2020-05-28');
insert into employee values(108, "simran kaur", "Finance", "mumbai", 58000, '2021-08-03');
insert into employee values(109, "arjun reddy", "IT", "hyderabad", 70000, '2022-02-18');
insert into employee values(110, "anjali das", "sales", "kolkata", 51000, '2023-01-15');



#1 SELECT *
FROM employee
WHERE department IN ('IT', 'HR');

#2 SELECT *
FROM employee
WHERE department IN ('sales', 'IT', 'Finance');

#3 SELECT *
FROM employee
WHERE salary BETWEEN 50000 AND 70000;

#4 SELECT *
FROM employee
WHERE emp_name LIKE 'a%';

#5 SELECT *
FROM employee
WHERE emp_name LIKE '%an%';

#6 SELECT *
FROM employee
WHERE city IN ('delhi', 'mumbai')
AND salary > 55000;

#7 SELECT *
FROM employee
WHERE department <> 'HR';

#8 SELECT *
FROM employee
WHERE hire_date BETWEEN '2019-01-01' AND '2022-12-31'
ORDER BY hire_date ASC;
