# %% [markdown]
# #1.    to check that the data contains the missing values
#
# #Solution:-  mentioned in the coding
#
# #2.   to check the distribution of the data which contains null value using  histrogram
#
# #solution:-   mentioned in the coding
#
# #3. fill the missing values by using mean median and mode for categorical data
#
# #Solution:-  mentioned in the coding   you have to follow the same steps for all the columns where there is missing values are present and you have to use mean and median of the data based on the distribuion of the data   whether that data is normal or skeweed (if the data is skeweed then you have to use median  and if the data is normal then you have to use mean )
#
# #4.  to detect datatype of every column
#
# #solution:-  mentioned in the coding
#
# #5.  select the columns with integer values which has outliers then make chart and detect outliers
#
# #solution:-  mentioned in the coding
#
#
# #6.  remove the outliers   (from those columns where there is outliers )
#
# #solution:-  mentioned in the coding
#
#
#
# #7.   to encoding the data of required coloumn
#
# #solution:-  mentioned in the coding
#
#
# #8.  for the scaling of the data
#
# #Solution:-  mentioned in the coding  for that you have to  make a numerical dataframe column and make a different dataframe for categorical data

# %%
#1 df1. isnull().sum()

#2  import matplotlib.pylot as plt
    import seaborn as sns

#3  df1{"RestingBP"} = df1{"RestingBP"} . fillna(df1{"RestingBP"}.median/mean())

#4  df1.datatypes

#5 sns.boxplot(x=df1{"age"})
   plt.show()

#6 q1 = df1{"RestingBP"} . quantile(0.25)
   q3 = df1{"RestingBP"} . quantile(0.75)
   iqr = q3-q1
   lower = q1-1.5*iqr
   upper = q3+1.5*iqr

   df1 = {(df1{"RestingBP"} >= lower) & (df1{"RestingBP"} <= upper)}


#7  df = pd.get_dumies(df1,columns = {"sex","chestpain"}, drop_first = true)
    df1.head()


#8 #a.  df_num = df1_c{{'age','RestingBP'}}
        df_num = df1_c{{'fever', 'diet'}}

  #b.   from sklearn.preprocessing import robust scaler
        scaler = standardscaler()
        df_num = scaler.fit_transform(df_num)------ this will give you arrey


        df_num = pd.dataframe(df_num, columns = {'age', 'RestingBP'})
        df_num
